# %%
# supress warnings
import warnings

warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks

# %%
df = pd.DataFrame(pd.read_csv("diamonds.csv"))

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.shape
# Out:
# (53940, 11)

# %% [markdown]
# # Data Inspection

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   carat     53940 non-null  float64
#  1   cut       53940 non-null  object
#  2   color     53940 non-null  object
#  3   clarity   53940 non-null  object
#  4   depth     53940 non-null  float64
#  5   table     53940 non-null  float64
#  6   price     53940 non-null  int64
#  7   x         53940 non-null  float64
#  8   y         53940 non-null  float64
#  9   z         53940 non-null  float64
#  10  cut_type  53940 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 4.5+ MB

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z', 'cut_type'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis='columns',inplace=True)
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#Dropping dimentionless diamonds
df = df.drop(df[df["x"]==0].index)
df = df.drop(df[df["y"]==0].index)
df = df.drop(df[df["z"]==0].index)
df.shape
# Out:
# (53920, 11)

# %%
df.isna().sum()
# Out:
# carat       0
# cut         0
# color       0
# clarity     0
# depth       0
# table       0
# price       0
# x           0
# y           0
# z           0
# cut_type    0
# dtype: int64

# %%
df.isnull().sum() * 100 / df.shape[0]
# Out:
# carat       0.0
# cut         0.0
# color       0.0
# clarity     0.0
# depth       0.0
# table       0.0
# price       0.0
# x           0.0
# y           0.0
# z           0.0
# cut_type    0.0
# dtype: float64

# %%
df.price.describe()
# Out:
# count    53920.000000
# mean      3930.993231
# std       3987.280446
# min        326.000000
# 25%        949.000000
# 50%       2401.000000
# 75%       5323.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
sns.distplot(df['price'])
plt.show()

# %% [markdown]
# # EDA

# %%
sns.pairplot(df)

# %%
plt1 = sns.countplot(df['table'])
plt1.set(xlabel='table', ylabel='no of diamonds')
plt.tight_layout()
plt.show()

# %%
df_sym = pd.DataFrame(df['table'].value_counts())
df_sym.plot.pie(subplots=True,
                labels=df_sym.index.values,
                autopct='%1.1f%%',
                figsize=(15, 7.5))
# Unsquish the pie.
plt.gca().set_aspect('equal')
plt.tight_layout()
plt.show()

# %%
df.cut.values[0:10]
# Out:
# array(['Ideal', 'Premium', 'Good', 'Premium', 'Good', 'Very Good',
#        'Very Good', 'Very Good', 'Fair', 'Very Good'], dtype=object)

# %%
df['cut_type'] = df.cut.str.split(' ').str.get(0).str.upper()

# %%
len(set(df.cut_type.values))
# Out:
# 5

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt1 = sns.countplot(
    df['cut_type'],
    order=pd.value_counts(df['cut_type']).index,
)
plt1.set(xlabel='cut', ylabel='Count ')
xticks(rotation=90)
plt.show()
plt.tight_layout()

# %%
df.cut_type.describe()
# Out:
# count     53920
# unique        5
# top       IDEAL
# freq      21548
# Name: cut_type, dtype: object

# %%
df_comp_avg_price = df[['cut_type', 'price']].groupby(
    "cut_type",
    as_index=False).mean().rename(columns={'price': 'brand_avg_price'})
plt1 = df_comp_avg_price.plot(x='cut_type',
                              kind='bar',
                              legend=False,
                              sort_columns=True,
                              figsize=(15, 3))
plt1.set_xlabel("Brand")
plt1.set_ylabel("Avg Price (Dollars)")
xticks(rotation=90)
plt.show()

# %%
df_x_avg_price = df[['x', 'price']].groupby(
    "x",
    as_index=False).mean().rename(columns={'price': 'door_avg_price'})
plt1 = df_x_avg_price.plot(x='x',
                              kind='bar',
                              legend=False,
                              sort_columns=True)
plt1.set_xlabel("x")
plt1.set_ylabel("Avg Price (Dollars)")
xticks(rotation=0)
plt.show()

# %%
sns.scatterplot(x='carat',y='price',hue='cut', data =df)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='x',y='price',hue='cut', data =df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='price'>

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   cut_type
# 0    IDEAL
# 1  PREMIUM
# 2     GOOD
# 3  PREMIUM
# 4     GOOD

# %%
sns.lmplot(x="carat",y="price",data=df)

# %%
plt.figure(figsize=(10, 20))
plt.subplot(4, 2, 1)
sns.boxplot(x='color', y='price', data=df)
plt.subplot(4, 2, 2)
sns.boxplot(x='clarity', y='price', data=df)
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 10))
plt1 = sns.scatterplot(x='x', y='price', data=df, ax=axs[0, 0])
plt1.set_xlabel('x')
plt1.set_ylabel('Price of Car ')
plt2 = sns.scatterplot(x='y', y='price', data=df, ax=axs[0, 1])
plt2.set_xlabel('y)')
plt2.set_ylabel('Price of Car ')
plt3 = sns.scatterplot(x='z', y='price', data=df, ax=axs[1, 0])
plt3.set_xlabel('z')
plt3.set_ylabel('Price of Car')
plt.tight_layout()

# %%
df.color.describe()
# Out:
# count     53920
# unique        7
# top           G
# freq      11284
# Name: color, dtype: object

# %%
df_comp_avg_price = df[['color', 'price']].groupby(
    "color",
    as_index=False).mean().rename(columns={'price': 'brand_avg_price'})
plt1 = df_comp_avg_price.plot(x='color',
                              kind='bar',
                              legend=False,
                              sort_columns=True,
                              figsize=(15, 3))
plt1.set_xlabel("Color")
plt1.set_ylabel("Price")
xticks(rotation=90)
plt.show()

# %%
df.clarity.describe()
# Out:
# count     53920
# unique        8
# top         SI1
# freq      13063
# Name: clarity, dtype: object

# %%
df_comp_avg_price = df[['clarity', 'price']].groupby(
    "clarity",
    as_index=False).mean().rename(columns={'price': 'brand_avg_price'})
plt1 = df_comp_avg_price.plot(x='clarity',
                              kind='bar',
                              legend=False,
                              sort_columns=True,
                              figsize=(15, 3))
plt1.set_xlabel("Clarity")
plt1.set_ylabel("Price")
xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x="x",y="carat",data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='carat'>

# %%
# Let's check the correlation coefficients to see which variables are highly correlated

plt.figure(figsize=(16, 10))
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
sns.boxplot(x="color",y="price",data=df)
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %% [markdown]
# # Linear Regression Model

# %%
auto = df[[
    'carat','price','x','y','z'
]]

# %%
auto.head()
# Out:
#    carat  price     x     y     z
# 0   0.23    326  3.95  3.98  2.43
# 1   0.21    326  3.89  3.84  2.31
# 2   0.23    327  4.05  4.07  2.31
# 3   0.29    334  4.20  4.23  2.63
# 4   0.31    335  4.34  4.35  2.75

# %% [markdown]
# # Visualising the Data

# %%
plt.figure(figsize=(15, 15))
sns.pairplot(auto)
plt.show()

# %% [markdown]
# # Data Preparation

# %%
# auto = pd.get_dummies(auto,
#                       columns=[
#                           'cut_type'
#                       ],
#                       drop_first=True)

# %%
auto.shape
# Out:
# (53920, 5)

# %%
auto.head()
# Out:
#    carat  price     x     y     z
# 0   0.23    326  3.95  3.98  2.43
# 1   0.21    326  3.89  3.84  2.31
# 2   0.23    327  4.05  4.07  2.31
# 3   0.29    334  4.20  4.23  2.63
# 4   0.31    335  4.34  4.35  2.75

# %%
pd.set_option('display.max_columns', None)
auto.head()
# Out:
#    carat  price     x     y     z
# 0   0.23    326  3.95  3.98  2.43
# 1   0.21    326  3.89  3.84  2.31
# 2   0.23    327  4.05  4.07  2.31
# 3   0.29    334  4.20  4.23  2.63
# 4   0.31    335  4.34  4.35  2.75

# %% [markdown]
# ## Rescaling the Features

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# Apply scaler() to all the columns except the 'dummy' variables
num_vars = [
    'carat','price', 'x', 'y', 'z'
]

auto[num_vars] = scaler.fit_transform(auto[num_vars])

# %%
auto.head()
# Out:
#       carat     price         x         y         z
# 0  0.006237  0.000000  0.031384  0.005433  0.044256
# 1  0.002079  0.000000  0.022825  0.002898  0.040351
# 2  0.006237  0.000054  0.045649  0.007063  0.040351
# 3  0.018711  0.000433  0.067047  0.009960  0.050765
# 4  0.022869  0.000487  0.087019  0.012133  0.054670

# %%
auto.describe()
# Out:
#               carat         price             x             y             z
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean       0.124262      0.194896      0.285539      0.037213      0.080379
# std        0.098502      0.215564      0.159689      0.020647      0.022861
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.041580      0.033681      0.139800      0.018834      0.059876
# 50%        0.103950      0.112180      0.281027      0.036762      0.080052
# 75%        0.174636      0.270165      0.400856      0.051793      0.096648
# max        1.000000      1.000000      1.000000      1.000000      1.000000

# %%
# Let's check the correlation coefficients to see which variables are highly correlated

plt.figure(figsize=(16, 10))
sns.heatmap(df_train.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# # Dividing into X and Y sets for the model building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# ### Diamond Price Prediction using Carat , x, y, z

# %%
#Independent Variable
X = auto[['carat','x','y','z']]
X
# Out:
#           carat         x         y         z
# 0      0.006237  0.031384  0.005433  0.044256
# 1      0.002079  0.022825  0.002898  0.040351
# 2      0.006237  0.045649  0.007063  0.040351
# 3      0.018711  0.067047  0.009960  0.050765
# 4      0.022869  0.087019  0.012133  0.054670
# ...         ...       ...       ...       ...
# 53935  0.108108  0.288160  0.037668  0.079076
# 53936  0.108108  0.279601  0.037486  0.082655
# 53937  0.103950  0.275321  0.036219  0.081028
# 53938  0.137214  0.345221  0.044187  0.086886
# 53939  0.114345  0.299572  0.039660  0.083632
#
# [53920 rows x 4 columns]

# %%
#dependent variable 
Y = auto['price']
Y
# Out:
# 0        0.000000
# 1        0.000000
# 2        0.000054
# 3        0.000433
# 4        0.000487
#            ...
# 53935    0.131427
# 53936    0.131427
# 53937    0.131427
# 53938    0.131427
# 53939    0.131427
# Name: price, Length: 53920, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=100)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (43136, 4)
# (10784, 4)
# (43136,)
# (10784,)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([0.25822881, 0.017491  , 0.22193651, ..., 0.03862314, 0.13593561,
#        0.14818829])

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8335895361432496

# %% [markdown]
# ### Carat Prediction using X

# %%
#Independent Variable
X = auto[['x']]
X
# Out:
#               x
# 0      0.031384
# 1      0.022825
# 2      0.045649
# 3      0.067047
# 4      0.087019
# ...         ...
# 53935  0.288160
# 53936  0.279601
# 53937  0.275321
# 53938  0.345221
# 53939  0.299572
#
# [53920 rows x 1 columns]

# %%
#dependent variable 
Y = auto['carat']
Y
# Out:
# 0        0.006237
# 1        0.002079
# 2        0.006237
# 3        0.018711
# 4        0.022869
#            ...
# 53935    0.108108
# 53936    0.108108
# 53937    0.103950
# 53938    0.137214
# 53939    0.114345
# Name: carat, Length: 53920, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=100)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (43136, 1)
# (10784, 1)
# (43136,)
# (10784,)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([0.17414031, 0.01655056, 0.16208426, ..., 0.04324609, 0.11558237,
#        0.12591612])

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9556496193110666
